# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Visit the URL
url = "https://globalvoices.org/page/2/"
browser.visit(url)

# Parse the HTML
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Close the dialogue box
browser.links.find_by_partial_text('No thanks').click()

# %%
# Create a function to perform the web scraping
def get_summary():
    # Collect the HTML from the browser
    html = browser.html

    # Parse the HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')

    # Save the main area of the web page to a variable
    m = soup.find('div', class_='post-archive-container')

    # Find all the articles in the main area of the web page
    article_list = m.find_all('div', class_='gv-promo-card-text')
    
    # Create an empty list to hold summaries
    summaries = []
    
    # Loop through the articles
    for _ in article_list:
    
        # Collect the article title
        title = _.find('h3', class_='post-title').text

        # Collect the article date
        date = _.find('span', class_='datestamp')['title']

        # Remove the underscore from the date
        date = date.replace('_', '')
        
        # Create the summary dictionary
        row = {'header': title, 'date': date}
        # Append the summary dictionary to the list
        summaries.append(row)
        
    # Return the list of summaries
    return summaries

# %%
# Create a loop to collect the article summaries and click to the older article pages 5 times
articles = []
for _ in range(5):
    articles.extend(get_summary())
    browser.links.find_by_partial_text('Older').click()

# %%
# Print the articles list
articles
# Out:
# [{'header': 'A writer thriving in the Nepali diaspora: An interview with Krishna Bajgai',
#   'date': '18 08 2023'},
#  {'header': 'Why people are voting for ‘anarco-capitalist’ Milei, from an Argentinian perspective',
#   'date': '18 08 2023'},
#  {'header': 'Concerns in Guyana about threats against women activists',
#   'date': '17 08 2023'},
#  {'header': 'The state of scientific development in Venezuela: Observations of a distinguished scientist',
#   'date': '17 08 2023'},
#  {'header': "Museveni challenges World Bank's decision on loan suspension over anti-LGBTQ+ law in Uganda",
#   'date': '17 08 2023'},
#  {'header': 'Digital activist discusses why native Yoruba speakers should embrace their Indigenous language in online spaces',
#   'date': '17 08 2023'},
#  {'header': 'Ahead of election, Pakistan introduces new laws to stifle dissent',
#   'date': '17 08 2023'},
#  {'header': 'African institutions maintain silence on sub-Saharan migrant rights abuses in Tunisia',
#   'date': '17 08 2023'},
#  {'header': "‘I haven't seen a tree in three years’: An Australian journalist’s prison letter from China",
#   'date': '17 08 2023'},
#  {'header': "A peek into Taiwan's small Jewish community: Interview with Rabbi Cody Bahir",
#   'date': '17 08 2023'},
#  {'header': 'Meet two Jamaican disability advocates who want vulnerable communities to become climate resilient',
#   'date': '16 08 2023'},
#  {'header': "Jordan's fight for online freedom of expression",
#   'date': '16 08 2023'},
#  {'header': 'Gay couple fled from Russia to Moldova due to war and homophobia',
#   'date': '16 08 2023'},
#  {'header': 'Is the exiled Iranian queer community finally getting acceptance in the Iranian diaspora?',
#   'date': '16 08 2023'},
#  {'header': "Undertones: Russia's war strengthens Venezuelan solidarity with Ukraine",
#   'date': '15 08 2023'},
#  {'header': "Hong Kong artist in exile in Taiwan uses protest art to resist Beijing's attacks on freedom in the region",
#   'date': '15 08 2023'},
#  {'header': 'In Azerbaijan, couriers are facing intimidation and arrests at the hands of the state',
#   'date': '15 08 2023'},
#  {'header': 'Unraveling the crackdown on LGBTQ+ rights in several African countries',
#   'date': '14 08 2023'},
#  {'header': 'For Venezuelans, the invasion of Ukraine hits close to home',
#   'date': '14 08 2023'},
#  {'header': 'A new platform monitoring press freedom in Southeast Asia',
#   'date': '14 08 2023'},
#  {'header': 'Dengue is becoming endemic in Bangladesh', 'date': '13 08 2023'},
#  {'header': 'Cultural appropriation and the erasure of cultural diversity',
#   'date': '12 08 2023'},
#  {'header': 'Chinese propaganda takes over a graffiti wall on London’s Brick Lane',
#   'date': '12 08 2023'},
#  {'header': 'World Steelpan Day honours the national instrument of Trinidad & Tobago',
#   'date': '11 08 2023'},
#  {'header': 'Suspectibility to conspiracy theories makes Western Balkans easy target for Russian disinformation, geopolitical analyst says',
#   'date': '11 08 2023'},
#  {'header': 'Serbian ruling party troll farm leak revealed identities of over 14,500 ‘bots’',
#   'date': '10 08 2023'},
#  {'header': 'Disinformation fuels church protest against gender equality in North Macedonia',
#   'date': '10 08 2023'},
#  {'header': 'African perspectives: the role of artificial intelligence in journalism',
#   'date': '10 08 2023'},
#  {'header': 'A podcast in Kazakhstan is under controversy for inviting a friend of the Boston Marathon bomber',
#   'date': '10 08 2023'},
#  {'header': 'Has digital media influenced environmentally sustainable practices in Nigeria?',
#   'date': '10 08 2023'},
#  {'header': 'As Jamaica reflects on 61 years of Independence, it also looks to its future',
#   'date': '9 08 2023'},
#  {'header': "‘My art is a tribute to my origins and childhood': An interview with Burkina Faso-born artist Saïdou Dicko",
#   'date': '9 08 2023'},
#  {'header': 'Ethnic clashes bring Indian state Manipur to the brink of civil war',
#   'date': '9 08 2023'},
#  {'header': "Uzbekistan's list of foreign policy challenges grows larger",
#   'date': '8 08 2023'},
#  {'header': 'What is ‘soft resistance’? Hong Kong officials vow to take a hard line against it, but provide no definition',
#   'date': '8 08 2023'},
#  {'header': 'Why Ghanaian women are struggling to breastfeed their babies for the recommended six months',
#   'date': '7 08 2023'},
#  {'header': "Africa reimagined: Burkina Faso's Ibrahim Traoré advocates for resilience, recognition, and resistance",
#   'date': '7 08 2023'},
#  {'header': 'Brazil: Oil exploitation project worries fishermen at Amazon River estuary',
#   'date': '7 08 2023'},
#  {'header': 'Transcending boundaries: Celebrating embodiment, pleasure, and resistance',
#   'date': '7 08 2023'},
#  {'header': "Zere's new album is a continuation of her fight against gender inequality in Kyrgyzstan",
#   'date': '7 08 2023'},
#  {'header': 'A starter guide to Chinese open source data for non-Chinese speakers',
#   'date': '7 08 2023'},
#  {'header': 'Devastating floods in Hebei expose the site selection problem of China’s sub-capital, Xiong’an',
#   'date': '6 08 2023'},
#  {'header': 'Myanmar junta grants partial pardon to detained leaders amid continuing crisis and resistance',
#   'date': '6 08 2023'},
#  {'header': 'Former Pakistan prime minister Imran Khan arrested once again ahead of elections',
#   'date': '6 08 2023'},
#  {'header': 'Hong Kong’s homegrown security law, Article 23, is back in the spotlight',
#   'date': '5 08 2023'},
#  {'header': 'The story of the ‘little Russian houses’ in Havana, Cuba, in photos',
#   'date': '4 08 2023'},
#  {'header': 'Unfreedom Monitor: Civic Media Observatory findings report',
#   'date': '4 08 2023'},
#  {'header': 'Why do we keep hiding the history of technology?',
#   'date': '4 08 2023'},
#  {'header': 'Bosnian Genocide commemoration in Tuzla: ‘We don’t harbor hatred, but we will never forget’',
#   'date': '4 08 2023'},
#  {'header': "Interview with Ukraine's most translated author, Russophone novelist Andrei Kurkov",
#   'date': '3 08 2023'},
#  {'header': 'The Loneliest Monument — how activists in Armenia are trying to draw attention to the victims of Soviet repression',
#   'date': '3 08 2023'},
#  {'header': 'How the onstage stunt of British band The 1975 caused more harm than good in Malaysia',
#   'date': '3 08 2023'},
#  {'header': "These women are fighting back on the continued destruction of Turkey's Akbelen forest",
#   'date': '3 08 2023'},
#  {'header': 'Latin America embraces Barbie through pink tacos, parodies and protests',
#   'date': '2 08 2023'},
#  {'header': 'One day with Azov instructors as a prospective soldier in Ukraine',
#   'date': '2 08 2023'},
#  {'header': 'The dreams of Saudi human rights defender Loujain Al-Hathloul in a children’s book',
#   'date': '1 08 2023'},
#  {'header': 'In Turkey, even university graduations are political',
#   'date': '1 08 2023'},
#  {'header': 'Why West Africa civil society organizations are urging ECOWAS to prioritize disability inclusion',
#   'date': '1 08 2023'},
#  {'header': 'Creating awareness is a crucial step to breaking the stigma of infertility in Africa',
#   'date': '1 08 2023'},
#  {'header': 'Why is Kyiv giving Taiwan the cold shoulder? Interview with Ukrainian MP Mykola Knyazhytskyy',
#   'date': '31 07 2023'},
#  {'header': 'Caribbean art exhibit portrays the threatened beauty of the ocean as deep-sea mining negotiations come to an end in Jamaica',
#   'date': '31 07 2023'},
#  {'header': 'Russian diplomats react to a new law on language in Kyrgyzstan, bringing back colonial past',
#   'date': '31 07 2023'},
#  {'header': 'Hong Kong court rejects government application for ban on pro-democracy protest song',
#   'date': '31 07 2023'},
#  {'header': 'Can Taiwan become a hub for journalists fleeing mounting authoritarianism in Asia?',
#   'date': '31 07 2023'},
#  {'header': 'Commentators discourage extending national security crackdowns to ‘soft resistance’ in Hong Kong',
#   'date': '29 07 2023'},
#  {'header': 'Sustainable innovations: Dang, Nepal turns dung into energy',
#   'date': '28 07 2023'},
#  {'header': 'Haitian refugees land on Jamaican shores, while CARICOM’s efforts to help its troubled member state falter',
#   'date': '28 07 2023'},
#  {'header': 'Can Algerian human rights defenders be safe in Tunisia?',
#   'date': '28 07 2023'},
#  {'header': 'A 1961 Senegalese novel shows the enduring wealth of African literature',
#   'date': '28 07 2023'},
#  {'header': 'An interview with Aïssatou Fofana, environmental investigative journalist in Ivory Coast',
#   'date': '28 07 2023'},
#  {'header': 'Mongolia turns to its dinosaurs in an attempt to attract more tourists',
#   'date': '28 07 2023'},
#  {'header': 'In Turkey, when forests are not on fire, they are being destroyed by greedy men in suits',
#   'date': '27 07 2023'},
#  {'header': 'The future of Ukrainian New York', 'date': '27 07 2023'},
#  {'header': 'New Taiwan TV series tackles sensitive issue of race and makes it to Netflix',
#   'date': '27 07 2023'},
#  {'header': 'Barbie in the Balkans: From disinformation to Yugonostalgia',
#   'date': '27 07 2023'},
#  {'header': "Taiwanese citizens take the nation's defense into their own hands: Interview with scholar Wen Liu",
#   'date': '27 07 2023'},
#  {'header': '‘Indigenous languages are asleep, not extinct,’ says Kokama linguistics researcher',
#   'date': '26 07 2023'},
#  {'header': "‘Welcome to Sex': Australian sex-ed book tops bestseller list, despite campaign to block sales",
#   'date': '26 07 2023'},
#  {'header': 'Mongolia and Kyrgyzstan commit to intensifying bilateral cooperation',
#   'date': '26 07 2023'},
#  {'header': 'A documentary showcases why some Taiwanese consider Southeast Asia a land of opportunity',
#   'date': '25 07 2023'},
#  {'header': "Permission to restore century-old houseboats in Kashmir's Dal Lake is a welcome move for tourism",
#   'date': '25 07 2023'},
#  {'header': 'How companies collect private data about reproductive health',
#   'date': '25 07 2023'},
#  {'header': 'The Great Leap Backwards of media in China',
#   'date': '24 07 2023'},
#  {'header': 'Kamnotra emerges as the latest platform in a ‘news-starved’ Cambodia',
#   'date': '24 07 2023'},
#  {'header': 'Women’s participation in Nigeria’s politics is moving backward: A call for action',
#   'date': '24 07 2023'},
#  {'header': 'Raffi Feghali defies censorship through improvisational theatre in Lebanon',
#   'date': '24 07 2023'},
#  {'header': "How India's Ho- and Santali-language content creators are holding space for Indigenous linguistic assertion",
#   'date': '24 07 2023'},
#  {'header': 'Togo finally gives its authors recognition in its school syllabus',
#   'date': '24 07 2023'},
#  {'header': 'Speculations about China’s Foreign Minister Qin Gang disappearance from the public eye include alleged affair and power struggle',
#   'date': '22 07 2023'},
#  {'header': 'Turkey has a long road ahead with renewed EU bid',
#   'date': '21 07 2023'},
#  {'header': 'A ‘diplomatic tiff’ over same-sex marriage is downplayed, but differences on LGBTQ+ issues remain in the Jamaica-U.S. relationship',
#   'date': '20 07 2023'},
#  {'header': 'In Turkey, conservatives go after a queer volleyball star',
#   'date': '20 07 2023'},
#  {'header': 'Undertones: Inside Russian influencer chats in Argentina',
#   'date': '20 07 2023'},
#  {'header': 'In Kazakhstan, the truth about the 2022 deadly protests is still suppressed',
#   'date': '20 07 2023'},
#  {'header': 'Turkmenistan unveils its first ‘smart’ city, named after the former president',
#   'date': '20 07 2023'},
#  {'header': 'Deconstructing the politics behind the mistreatment of migrants from Africa in Tunisia',
#   'date': '20 07 2023'},
#  {'header': "Fish are poured into Jamaica's Rio Cobre after pollution incidents, but is this the end of the matter?",
#   'date': '20 07 2023'},
#  {'header': 'Armenia and Azerbaijan: A blockade that never ended and a peace deal hanging by a thread',
#   'date': '19 07 2023'},
#  {'header': 'The wacky race: The road to the Egyptian Presidential elections in 2024',
#   'date': '19 07 2023'},
#  {'header': 'How will Tunisia include its growing poor in an increasingly digital society?',
#   'date': '19 07 2023'},
#  {'header': 'Protests condemn military-appointed senators for ignoring the choice of Thai voters',
#   'date': '18 07 2023'},
#  {'header': 'And then there were none — how political parties are disappearing in Azerbaijan',
#   'date': '18 07 2023'},
#  {'header': 'Digital nomads: Gentrification or economic boost?',
#   'date': '18 07 2023'},
#  {'header': 'The Belarus regime’s crackdown on civil society continues',
#   'date': '18 07 2023'},
#  {'header': 'Prolonged detention of activist draws anger in Angola',
#   'date': '18 07 2023'}]

# %%
# Import Pandas
import pandas as pd

# Convert the articles list to a Pandas DataFrame
df = pd.DataFrame(articles)
df.head()
# Out:
#                                               header        date
# 0  A writer thriving in the Nepali diaspora: An i...  18 08 2023
# 1  Why people are voting for ‘anarco-capitalist’ ...  18 08 2023
# 2  Concerns in Guyana about threats against women...  17 08 2023
# 3  The state of scientific development in Venezue...  17 08 2023
# 4  Museveni challenges World Bank's decision on l...  17 08 2023

# %%
# Convert the date column to a datetime data type
df.date = pd.to_datetime(df.date, dayfirst=True)

# %%
# Display the DataFrame
df
# Out:
#                                                 header       date
# 0    A writer thriving in the Nepali diaspora: An i... 2023-08-18
# 1    Why people are voting for ‘anarco-capitalist’ ... 2023-08-18
# 2    Concerns in Guyana about threats against women... 2023-08-17
# 3    The state of scientific development in Venezue... 2023-08-17
# 4    Museveni challenges World Bank's decision on l... 2023-08-17
# ..                                                 ...        ...
# 100  Protests condemn military-appointed senators f... 2023-07-18
# 101  And then there were none — how political parti... 2023-07-18
# 102  Digital nomads: Gentrification or economic boost? 2023-07-18
# 103  The Belarus regime’s crackdown on civil societ... 2023-07-18
# 104  Prolonged detention of activist draws anger in... 2023-07-18
#
# [105 rows x 2 columns]

# %%
# Check the DataFrame information to ensure the date is saved as a datetime data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   header  105 non-null    object
#  1   date    105 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.8+ KB

# %%
# Close the browser
browser.quit()
