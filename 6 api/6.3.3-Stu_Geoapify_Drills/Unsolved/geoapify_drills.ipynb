# %% [markdown]
# # Geoapify Drills
#
# Create code to answer each of the following questions.
#
# > **Hint:** You will need multiple target URLs and multiple API requests.

# %%
# Dependencies
import requests
import json
from pprint import pprint

# Import the API key
from config import geoapify_key

# %% [markdown]
# ## 1. What are the geocoordinates (latitude and longitude) of Brisbane, Australia?

# %%
# Set the search parameters
target_city = "Brisbane%20Australia"

# Build URL using the geocode endpoint
url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"

# %%
# Run request
x = requests.get(url).json()
# Print the json (pretty printed)
pprint(x)
# Out:
# {'query': {'parsed': {'city': 'brisbane',
#                       'country': 'australia',
#                       'expected_type': 'city'},
#            'text': 'Brisbane Australia'},
#  'results': [{'address_line1': 'Brisbane City',
#               'address_line2': 'QLD, Australia',
#               'bbox': {'lat1': -27.660219,
#                        'lat2': -27.022014,
#                        'lon1': 152.679693,
#                        'lon2': 153.468275},
#               'category': 'administrative',
#               'city': 'Brisbane City',
#               'country': 'Australia',
#               'country_code': 'au',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': 'Brisbane City, QLD, Australia',
#               'lat': -27.4689682,
#               'lon': 153.0234991,
#               'place_id': '51893f2f81c0206340592eddc94c0e783bc0f00101f9016030b20000000000c00208',
#               'plus_code': '5R4MG2JF+C9',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.8694082277592821,
#                        'match_type': 'full_match',
#                        'popularity': 6.876406158741578},
#               'result_type': 'city',
#               'state': 'Queensland',
#               'state_code': 'QLD',
#               'timezone': {'abbreviation_DST': 'AEST',
#                            'abbreviation_STD': 'AEST',
#                            'name': 'Australia/Brisbane',
#                            'offset_DST': '+10:00',
#                            'offset_DST_seconds': 36000,
#                            'offset_STD': '+10:00',
#                            'offset_STD_seconds': 36000}}]}

# %%
# Extract lat/lon
brisbane_lat = x['results'][0]['lat']
brisbane_lon = x['results'][0]['lon']

# Print results
print(f'Brisbane, Australia: {brisbane_lat}, {brisbane_lon}')
# Out:
# Brisbane, Australia: -27.4689682, 153.0234991

# %% [markdown]
# ## 2. What are the geocoordinates (latitude and longitude) of The Sydney Opera House?

# %%
# update params dict
opera_house = "Sydney%20Opera%20House%20Sydney%20Australia"

# Build URL using the geocode endpoint
url = f"https://api.geoapify.com/v1/geocode/search?text={opera_house}&format=json&apiKey={geoapify_key}"

# %%
# Run request
x = requests.get(url).json()
# Print the json (pretty printed)
pprint(x)
# Out:
# {'query': {'parsed': {'city': 'sydney',
#                       'country': 'australia',
#                       'expected_type': 'amenity',
#                       'house': 'sydney opera house'},
#            'text': 'Sydney Opera House Sydney Australia'},
#  'results': [{'address_line1': 'Sydney Opera House',
#               'address_line2': '2 Macquarie Street, Sydney NSW 2000, Australia',
#               'bbox': {'lat1': -33.8579291,
#                        'lat2': -33.856305,
#                        'lon1': 151.214428,
#                        'lon2': 151.2158894},
#               'category': 'entertainment.culture.arts_centre',
#               'city': 'Sydney',
#               'country': 'Australia',
#               'country_code': 'au',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'district': 'Quay Quarter',
#               'formatted': 'Sydney Opera House, 2 Macquarie Street, Sydney NSW '
#                            '2000, Australia',
#               'housenumber': '2',
#               'lat': -33.85719805,
#               'lon': 151.21512338473752,
#               'municipality': 'Council of the City of Sydney',
#               'name': 'Sydney Opera House',
#               'place_id': '51aec16f4ae2e6624059f5786baab8ed40c0f00101f901c86f920000000000c002019203125379646e6579204f7065726120486f757365',
#               'plus_code': '4RRH46V8+42',
#               'plus_code_short': 'V8+42 Sydney, New South Wales, Australia',
#               'postcode': '2000',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'importance': 0.9339868225769328,
#                        'match_type': 'full_match',
#                        'popularity': 6.979585085597298},
#               'result_type': 'amenity',
#               'state': 'New South Wales',
#               'state_code': 'NSW',
#               'street': 'Macquarie Street',
#               'suburb': 'Sydney',
#               'timezone': {'abbreviation_DST': 'AEDT',
#                            'abbreviation_STD': 'AEST',
#                            'name': 'Australia/Sydney',
#                            'offset_DST': '+11:00',
#                            'offset_DST_seconds': 39600,
#                            'offset_STD': '+10:00',
#                            'offset_STD_seconds': 36000}}]}

# %%
# Extract lat/lon
opera_lat = x['results'][0]['lat']
opera_lon = x['results'][0]['lon']
# Print results
print(f"Sydney Opera House: {opera_lat} {opera_lon}")
# Out:
# Sydney Opera House: -33.85719805 151.21512338473752

# %% [markdown]
# ## 3. Find the name and address of a pharmacy in Brisbane, Australia.
#
# > **Hint:** Review <https://apidocs.geoapify.com/docs/places/#categories>.

# %%
# set up a parameters dictionary
params = {
    # Set the geographical coordinates for Brisbane, Australia
    'lat': brisbane_lat,
    'lon': brisbane_lon,
    # Set the parameters for the type of place
    'type': 'pharmacy',
    # Set the parameters for the type of search
    'search_type': 'nearby',
    'categories': 'healthcare.pharmacy',
    'apiKey': geoapify_key,
}

# Set base URL
# NOTE!! I switched from v1 to v2 to get the params to work
url = f"https://api.geoapify.com/v2/places"

# Run request
x = requests.get(url, params=params).json()

# Print the json (pretty printed)
pprint(x)
# Out:
# {'features': [{'geometry': {'coordinates': [153.024774, -27.46900499946224],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Wizard Pharmacy',
#                               'address_line2': 'Queen Street Mall, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Wizard Pharmacy',
#                                                      'osm_id': 6320207377,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 126,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Wizard Pharmacy, Queen Street '
#                                            'Mall, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'lat': -27.469005,
#                               'lon': 153.024774,
#                               'name': 'Wizard Pharmacy',
#                               'place_id': '5151f9d7f2ca20634059cf592eb610783bc0f00103f90111b6b6780100000092030f57697a61726420506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street Mall',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0250366, -27.468689399462253],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '160 Queen Street, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '07:00-16:00, '
#                                                                       '09:00-18:00; '
#                                                                       'Sa '
#                                                                       '09:00-14:00',
#                                                      'osm_id': 4310080112,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 155,
#                               'district': 'Brisbane City',
#                               'formatted': 'Priceline Pharmacy, 160 Queen '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '160',
#                               'lat': -27.4686894,
#                               'lon': 153.0250366,
#                               'name': 'Priceline Pharmacy',
#                               'place_id': '517f468e19cd2063405919ac4a07fc773bc0f00103f901709ae6000100000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02486289999996,
#                                             -27.469754799462155],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '120 Queen Street, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'osm_id': 1546536181,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 161,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Priceline Pharmacy, 120 Queen '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '120',
#                               'lat': -27.4697548,
#                               'lon': 153.0248629,
#                               'name': 'Priceline Pharmacy',
#                               'place_id': '5146cc47adcb2063405939d4bcd941783bc0f00103f901f5442e5c0000000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0217986, -27.469351399462198],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Wizard Pharmacy',
#                               'address_line2': '336 George Street, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Wizard Pharmacy',
#                                                      'osm_id': 1546700978,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 173,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Wizard Pharmacy, 336 George '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '336',
#                               'lat': -27.4693514,
#                               'lon': 153.0217986,
#                               'name': 'Wizard Pharmacy',
#                               'place_id': '512843fa92b220634059a005cf6927783bc0f00103f901b2c8305c0000000092030f57697a61726420506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'George Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0238264, -27.47057739946206],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Chemist Warehouse',
#                               'address_line2': '60 Queen Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Chemist '
#                                                               'Warehouse',
#                                                      'brand:wikidata': 'Q48782120',
#                                                      'brand:wikipedia': 'en:Chemist '
#                                                                         'Warehouse',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Chemist '
#                                                              'Warehouse',
#                                                      'osm_id': 5151109719,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 181,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Chemist Warehouse, 60 Queen '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '60',
#                               'lat': -27.4705774,
#                               'lon': 153.0238264,
#                               'name': 'Chemist Warehouse',
#                               'place_id': '510119952fc32063405920edacc277783bc0f00103f90157b20733010000009203114368656d6973742057617265686f757365',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.027627, -27.468605199462253],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': 'Edward Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'osm_id': 8140167944,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 410,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Priceline Pharmacy, Edward Street, '
#                                            'Brisbane City QLD 4000, Australia',
#                               'lat': -27.4686052,
#                               'lon': 153.027627,
#                               'name': 'Priceline Pharmacy',
#                               'place_id': '5192af0452e2206340590a6da682f6773bc0f00103f901081b31e50100000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Edward Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02753079999997,
#                                             -27.46753149946238],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Post Office Square Pharmacy',
#                               'address_line2': 'Queen Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city_district': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'layer': -1,
#                                                      'name': 'Post Office '
#                                                              'Square Pharmacy',
#                                                      'osm_id': 1546982742,
#                                                      'osm_type': 'n',
#                                                      'toilets:wheelchair': 'no',
#                                                      'wheelchair': 'yes',
#                                                      'wheelchair:description': 'Accessible '
#                                                                                'via '
#                                                                                'Adelaide '
#                                                                                'Street '
#                                                                                'entrance'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.facilities'],
#                               'distance': 429,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Post Office Square Pharmacy, Queen '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'lat': -27.4675315,
#                               'lon': 153.0275308,
#                               'name': 'Post Office Square Pharmacy',
#                               'place_id': '513eb44588e1206340596f0af424b0773bc0f00103f9015615355c0000000092031b506f7374204f66666963652053717561726520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Queen Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0268978, -27.47154169946197],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '108 Albert Street, Brisbane '
#                                                'City QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'osm_id': 1541754211,
#                                                      'osm_type': 'n',
#                                                      'toilets:wheelchair': 'no',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 441,
#                               'district': 'Brisbane City',
#                               'formatted': 'Priceline Pharmacy, 108 Albert '
#                                            'Street, Brisbane City QLD 4000, '
#                                            'Australia',
#                               'housenumber': '108',
#                               'lat': -27.4715417,
#                               'lon': 153.0268978,
#                               'name': 'Priceline Pharmacy',
#                               'place_id': '51b36ac658dc20634059b1e3f1f4b6783bc0f00103f901634de55b0000000092031250726963656c696e6520506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Albert Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02900749999998,
#                                             -27.47025849946209],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Chemist Warehouse',
#                               'address_line2': 'Edward Street, Brisbane City '
#                                                'QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:state': 'QLD',
#                                                      'addr:suburb': 'Brisbane',
#                                                      'amenity': 'pharmacy',
#                                                      'brand': 'Chemist '
#                                                               'Warehouse',
#                                                      'brand:wikidata': 'Q48782120',
#                                                      'brand:wikipedia': 'en:Chemist '
#                                                                         'Warehouse',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Chemist '
#                                                              'Warehouse',
#                                                      'osm_id': 8140167945,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 563,
#                               'district': 'Brisbane City',
#                               'formatted': 'Chemist Warehouse, Edward Street, '
#                                            'Brisbane City QLD 4000, Australia',
#                               'lat': -27.4702585,
#                               'lon': 153.0290075,
#                               'name': 'Chemist Warehouse',
#                               'place_id': '51d6fa22a1ed2063405910db6bdc62783bc0f00103f901091b31e5010000009203114368656d6973742057617265686f757365',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Edward Street',
#                               'suburb': 'Brisbane City'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0139689, -27.46541889946259],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Barracks Pharmacy',
#                               'address_line2': '61 Petrie Terrace, Petrie '
#                                                'Terrace QLD 4000, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city': 'Brisbane City',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Barracks '
#                                                              'Pharmacy',
#                                                      'opening_hours': 'Mo-We,Fr '
#                                                                       '08:00-17:00, '
#                                                                       'Th '
#                                                                       '08:00-19:30, '
#                                                                       'Sa '
#                                                                       '08:00-14:00, '
#                                                                       'Su '
#                                                                       '09:00-13:00',
#                                                      'osm_id': 5045884261,
#                                                      'osm_type': 'n',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 1021,
#                               'district': 'Petrie Terrace',
#                               'formatted': 'Barracks Pharmacy, 61 Petrie '
#                                            'Terrace, Petrie Terrace QLD 4000, '
#                                            'Australia',
#                               'housenumber': '61',
#                               'lat': -27.4654189,
#                               'lon': 153.0139689,
#                               'name': 'Barracks Pharmacy',
#                               'place_id': '512815e86e7220634059d42168b125773bc0f00103f9016515c22c010000009203114261727261636b7320506861726d616379',
#                               'postcode': '4000',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Petrie Terrace',
#                               'suburb': 'Petrie Terrace'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.03050839999997,
#                                             -27.46199189946293],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Priceline Pharmacy',
#                               'address_line2': '365 Turbot Street, Fortitude '
#                                                'Valley QLD, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Spring Hill',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'Priceline '
#                                                               'Pharmacy',
#                                                      'brand:wikidata': 'Q7242652',
#                                                      'brand:wikipedia': 'en:Priceline '
#                                                                         '(Australia)',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Priceline '
#                                                              'Pharmacy',
#                                                      'name:en': 'Priceline '
#                                                                 'Pharmacy',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '08:00-19:00; '
#                                                                       'Sa '
#                                                                       '09:00-17:00; '
#                                                                       'Su '
#                                                                       '10:00-16:00',
#                                                      'osm_id': 4797796121,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1038,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Priceline Pharmacy, 365 Turbot '
#                                            'Street, Fortitude Valley QLD, '
#                                            'Australia',
#                               'housenumber': '365',
#                               'lat': -27.4619919,
#                               'lon': 153.0305084,
#                               'name': 'Priceline Pharmacy',
#                               'place_id': '511a88c0ecf920634059d035e31945763bc0f00103f901198ff81d0100000092031250726963656c696e6520506861726d616379',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Turbot Street',
#                               'suburb': 'Fortitude Valley'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.01198620000002,
#                                             -27.476914599461413],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'West End Discount Drug Stores',
#                               'address_line2': 'Mollison Street, West End QLD '
#                                                '4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'South Brisbane',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:postcode': 4101,
#                                                      'amenity': 'pharmacy',
#                                                      'name': 'West End '
#                                                              'Discount Drug '
#                                                              'Stores',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '08:00-20:00; '
#                                                                       'Sa '
#                                                                       '08:00-17:00; '
#                                                                       'Su '
#                                                                       '09:00-18:00',
#                                                      'osm_id': 506174931,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1439,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'West End Discount Drug Stores, '
#                                            'Mollison Street, West End QLD '
#                                            '4101, Australia',
#                               'lat': -27.4769146,
#                               'lon': 153.0119862,
#                               'name': 'West End Discount Drug Stores',
#                               'place_id': '511c20e2306220634059f5ab3f13177a3bc0f00103f901d39d2b1e0000000092031d5765737420456e6420446973636f756e7420447275672053746f726573',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Mollison Street',
#                               'suburb': 'West End'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.02356549999996,
#                                             -27.482002499460897],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'TerryWhite Chemmart',
#                               'address_line2': 'Grey Street, South Brisbane '
#                                                'QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'South Brisbane',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'TerryWhite '
#                                                               'Chemmart',
#                                                      'brand:wikidata': 'Q24089773',
#                                                      'brand:wikipedia': 'en:Terry '
#                                                                         'White '
#                                                                         'Chemmart',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'TerryWhite '
#                                                              'Chemmart',
#                                                      'osm_id': 8685936422,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1444,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'TerryWhite Chemmart, Grey Street, '
#                                            'South Brisbane QLD 4101, Australia',
#                               'lat': -27.4820025,
#                               'lon': 153.0235655,
#                               'name': 'TerryWhite Chemmart',
#                               'neighbourhood': 'South Bank',
#                               'place_id': '510a7a6f0cc1206340595ac60b84647b3bc0f00103f90126dfb8050200000092031354657272795768697465204368656d6d617274',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Grey Street',
#                               'suburb': 'South Brisbane'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0115955, -27.477398299461374],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'TerryWhite Chemmart',
#                               'address_line2': '97 Boundary Street, West End '
#                                                'QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'West End',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'TerryWhite '
#                                                               'Chemmart',
#                                                      'brand:wikidata': 'Q24089773',
#                                                      'brand:wikipedia': 'en:Terry '
#                                                                         'White '
#                                                                         'Chemmart',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'TerryWhite '
#                                                              'Chemmart',
#                                                      'osm_id': 8924429400,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1502,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'TerryWhite Chemmart, 97 Boundary '
#                                            'Street, West End QLD 4101, '
#                                            'Australia',
#                               'housenumber': '97',
#                               'lat': -27.4773983,
#                               'lon': 153.0115955,
#                               'name': 'TerryWhite Chemmart',
#                               'neighbourhood': 'Hill End',
#                               'place_id': '51fca886fd5e20634059455a63c6367a3bc0f00103f90158fcef130200000092031354657272795768697465204368656d6d617274',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Boundary Street',
#                               'suburb': 'West End'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0120306, -27.480687799461034],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Andrew Thanos Pharmacy',
#                               'address_line2': '197A Boundary Street, West End '
#                                                'QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city_district': 'West End',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': '197A',
#                                                      'addr:street': 'Boundary '
#                                                                     'Street',
#                                                      'amenity': 'pharmacy',
#                                                      'dispensing': 'yes',
#                                                      'drive_through': 'no',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Andrew Thanos '
#                                                              'Pharmacy',
#                                                      'osm_id': 5960364324,
#                                                      'osm_type': 'n',
#                                                      'phone': '+61738443086',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.contact',
#                                           'details.facilities'],
#                               'distance': 1724,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Andrew Thanos Pharmacy, 197A '
#                                            'Boundary Street, West End QLD '
#                                            '4101, Australia',
#                               'housenumber': '197A',
#                               'lat': -27.4806878,
#                               'lon': 153.0120306,
#                               'name': 'Andrew Thanos Pharmacy',
#                               'neighbourhood': 'Hill End',
#                               'place_id': '51a431ff8d622063405977450a5b0e7b3bc0f00103f90124f1436301000000920316416e64726577205468616e6f7320506861726d616379',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Boundary Street',
#                               'suburb': 'West End'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.01221809999998,
#                                             -27.480878899461022],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'TerryWhite Chemmart',
#                               'address_line2': '154 Boundary Street, West End '
#                                                'QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city_district': 'West End',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'brand': 'TerryWhite '
#                                                               'Chemmart',
#                                                      'brand:wikidata': 'Q24089773',
#                                                      'brand:wikipedia': 'en:Terry '
#                                                                         'White '
#                                                                         'Chemmart',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'TerryWhite '
#                                                              'Chemmart',
#                                                      'opening_hours': 'Mo-Sa '
#                                                                       '08:00-19:00; '
#                                                                       'Su '
#                                                                       '08:00-16:00',
#                                                      'opening_hours:covid19': 'open',
#                                                      'osm_id': 2798568500,
#                                                      'osm_type': 'n',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 1728,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'TerryWhite Chemmart, 154 Boundary '
#                                            'Street, West End QLD 4101, '
#                                            'Australia',
#                               'housenumber': '154',
#                               'lat': -27.4808789,
#                               'lon': 153.0122181,
#                               'name': 'TerryWhite Chemmart',
#                               'neighbourhood': 'Hill End',
#                               'place_id': '516a7d3617642063405985852ae11a7b3bc0f00103f90134c4cea60000000092031354657272795768697465204368656d6d617274',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Boundary Street',
#                               'suburb': 'West End'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0198823, -27.484505299460643],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Gladstone Road Pharmacy',
#                               'address_line2': '30-34 Gladstone Road, Highgate '
#                                                'Hill QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Highgate Hill',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'name': 'Gladstone Road '
#                                                              'Pharmacy',
#                                                      'osm_id': 506174928,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1758,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Gladstone Road Pharmacy, 30-34 '
#                                            'Gladstone Road, Highgate Hill QLD '
#                                            '4101, Australia',
#                               'housenumber': '30-34',
#                               'lat': -27.4845053,
#                               'lon': 153.0198823,
#                               'name': 'Gladstone Road Pharmacy',
#                               'place_id': '519e8834e0a22063405912ec0f8a087c3bc0f00103f901d09d2b1e00000000920317476c616473746f6e6520526f616420506861726d616379',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Gladstone Road',
#                               'suburb': 'Highgate Hill'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.03557819999997,
#                                             -27.48085839946103],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Coffey',
#                               'address_line2': 'Main Street, Kangaroo Point '
#                                                'QLD 4169, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city_district': 'Kangaroo Point',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Coffey',
#                                                      'osm_id': 6052259527,
#                                                      'osm_type': 'n',
#                                                      'wheelchair': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.facilities'],
#                               'distance': 1778,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Coffey, Main Street, Kangaroo '
#                                            'Point QLD 4169, Australia',
#                               'lat': -27.4808584,
#                               'lon': 153.0355782,
#                               'name': 'Coffey',
#                               'place_id': '516aaee474232163405929b13b89197b3bc0f00103f901c726be6801000000920306436f66666579',
#                               'postcode': '4169',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Main Street',
#                               'suburb': 'Kangaroo Point'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.0277626, -27.4849501994606],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Mater Pharmacy',
#                               'address_line2': 'Raymond Terrace, South '
#                                                'Brisbane QLD 4101, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'South Brisbane',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'dispensing': 'yes',
#                                                      'drive_through': 'no',
#                                                      'healthcare': 'pharmacy',
#                                                      'name': 'Mater Pharmacy',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '08:00-18:00',
#                                                      'osm_id': 6649314305,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1820,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Mater Pharmacy, Raymond Terrace, '
#                                            'South Brisbane QLD 4101, Australia',
#                               'lat': -27.4849502,
#                               'lon': 153.0277626,
#                               'name': 'Mater Pharmacy',
#                               'place_id': '51a961646ee32063405938df3eb2257c3bc0f00103f901017c548c0100000092030e4d6174657220506861726d616379',
#                               'postcode': '4101',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Raymond Terrace',
#                               'suburb': 'South Brisbane'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [153.00472009999996,
#                                             -27.471522299461956],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Choice Chemist',
#                               'address_line2': '41 Douglas Street, Milton QLD '
#                                                '4064, Australia',
#                               'categories': ['commercial.health_and_beauty',
#                                              'commercial.health_and_beauty.pharmacy',
#                                              'healthcare',
#                                              'healthcare.pharmacy'],
#                               'city_district': 'Milton',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'pharmacy',
#                                                      'dispensing': 'yes',
#                                                      'healthcare': 'pharmacy',
#                                                      'level': 2,
#                                                      'name': 'Choice Chemist',
#                                                      'osm_id': 5898069396,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1878,
#                               'district': 'Greater Brisbane',
#                               'formatted': 'Choice Chemist, 41 Douglas Street, '
#                                            'Milton QLD 4064, Australia',
#                               'housenumber': '41',
#                               'lat': -27.4715223,
#                               'lon': 153.0047201,
#                               'name': 'Choice Chemist',
#                               'place_id': '514764c4aa2620634059198677afb5783bc0f00103f90194658d5f0100000092030e43686f696365204368656d697374',
#                               'postcode': '4064',
#                               'state': 'Queensland',
#                               'state_code': 'QLD',
#                               'street': 'Douglas Street',
#                               'suburb': 'Milton'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print the results
print(f"""{x['features'][0]['properties']['address_line1']}
{x['features'][0]['properties']['address_line2']}""")
# Out:
# Wizard Pharmacy
# Queen Street Mall, Brisbane City QLD 4000, Australia

# %% [markdown]
# ## 4. Find a pet shop within a 5km radius from the Sydney Opera House.

# %% [markdown]
# ### I don't think it's filtering by 5km. I think it's returning the top 20 results

# %%
# set up a parameters dictionary
params = {
    # Set the geographical coordinates for the Sydney Opera House
    'lat': opera_lat,
    'lon': opera_lon,
    #'circle': f'opera_lon,opera_lat',
    # Set the parameters for the type of place
    'type': 'pet',
    # Set the parameters for the type of search
    #'search_type': 'nearby',
    'sort': 'distance',
    'radius': '5',
    'apiKey': geoapify_key,
}

# Set base URL
url = f"https://api.geoapify.com/v2/places"

# Run request
x = requests.get(url, params=params).json()

# Print the json (pretty printed)
pprint(x)
# Out:
# {'features': [{'geometry': {'coordinates': [151.22785899999997,
#                                             -33.87202299966735],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Healthy Everyday Pets',
#                               'address_line2': '43-47 Elizabeth Bay Road, '
#                                                'Elizabeth Bay NSW 2011, '
#                                                'Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'name': 'Healthy Everyday '
#                                                              'Pets',
#                                                      'osm_id': 10580904979,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 2023,
#                               'formatted': 'Healthy Everyday Pets, 43-47 '
#                                            'Elizabeth Bay Road, Elizabeth Bay '
#                                            'NSW 2011, Australia',
#                               'housenumber': '43-47',
#                               'lat': -33.872023,
#                               'lon': 151.227859,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Healthy Everyday Pets',
#                               'place_id': '512c23f59e4ae76240592e771c739eef40c0f00103f90113ccab76020000009203154865616c7468792045766572796461792050657473',
#                               'postcode': '2011',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Elizabeth Bay Road',
#                               'suburb': 'Elizabeth Bay'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.21709679999998,
#                                             -33.87775229966837],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Pawdressers',
#                               'address_line2': 'Eastern Distributor Onramp, '
#                                                'Darlinghurst NSW 2010, '
#                                                'Australia',
#                               'categories': ['commercial',
#                                              'pet',
#                                              'pet.service'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'description': 'Dog '
#                                                                     'grooming '
#                                                                     'and '
#                                                                     'daycare',
#                                                      'name': 'Pawdressers',
#                                                      'osm_id': 10053633558,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet_grooming'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 2287,
#                               'formatted': 'Pawdressers, Eastern Distributor '
#                                            'Onramp, Darlinghurst NSW 2010, '
#                                            'Australia',
#                               'lat': -33.8777523,
#                               'lon': 151.2170968,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Pawdressers',
#                               'place_id': '511e02fd74f2e66240594088f62f5af040c0f00103f90116463e570200000092030b5061776472657373657273',
#                               'postcode': '2010',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Eastern Distributor Onramp',
#                               'suburb': 'Darlinghurst'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2394564, -33.84184549966201],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Taronga Zoo Wildlife Hospital',
#                               'address_line2': 'Whiting Beach Road, Mosman NSW '
#                                                '2088, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'veterinary',
#                                                      'name': 'Taronga Zoo '
#                                                              'Wildlife '
#                                                              'Hospital',
#                                                      'osm_id': 9611865603,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 2823,
#                               'district': 'Lower North Shore',
#                               'formatted': 'Taronga Zoo Wildlife Hospital, '
#                                            'Whiting Beach Road, Mosman NSW '
#                                            '2088, Australia',
#                               'lat': -33.8418455,
#                               'lon': 151.2394564,
#                               'municipality': 'Mosman Municipal Council',
#                               'name': 'Taronga Zoo Wildlife Hospital',
#                               'place_id': '512cda77a0a9e7624059a3aae497c1eb40c0f00103f901036ee93c0200000092031d5461726f6e6761205a6f6f2057696c646c69666520486f73706974616c',
#                               'postcode': '2088',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Whiting Beach Road',
#                               'suburb': 'Mosman'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2252803, -33.884726599669605],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Paddington Cat Hospital',
#                               'address_line2': '210 Oxford Street, Paddington '
#                                                'NSW 2021, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': 210,
#                                                      'addr:street': 'Oxford '
#                                                                     'Street',
#                                                      'amenity': 'veterinary',
#                                                      'name': 'Paddington Cat '
#                                                              'Hospital',
#                                                      'osm_id': 5898635855,
#                                                      'osm_type': 'n',
#                                                      'wikidata': 'Q30260636'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.wiki_and_media'],
#                               'distance': 3195,
#                               'district': 'Eastern Suburbs',
#                               'formatted': 'Paddington Cat Hospital, 210 '
#                                            'Oxford Street, Paddington NSW '
#                                            '2021, Australia',
#                               'housenumber': '210',
#                               'lat': -33.8847266,
#                               'lon': 151.2252803,
#                               'municipality': 'Woollahra Municipal Council',
#                               'name': 'Paddington Cat Hospital',
#                               'neighbourhood': 'Five Ways',
#                               'place_id': '51dc1d087f35e7624059babda1b83ef140c0f00103f9014f0a965f0100000092031750616464696e67746f6e2043617420486f73706974616c',
#                               'postcode': '2021',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Oxford Street',
#                               'suburb': 'Paddington'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.18053139999998,
#                                             -33.857732799664824],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Beattie Street',
#                               'address_line2': 'Balmain NSW 2041, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'veterinary',
#                                                      'osm_id': 5114250531,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3202,
#                               'district': 'Inner West',
#                               'formatted': 'Beattie Street, Balmain NSW 2041, '
#                                            'Australia',
#                               'lat': -33.8577328,
#                               'lon': 151.1805314,
#                               'municipality': 'Inner West Council',
#                               'place_id': '51d55cc9e9c6e56240592ba23930caed40c0f00103f9012345d53001000000',
#                               'postcode': '2041',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Beattie Street',
#                               'suburb': 'Balmain'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.23033145854583,
#                                             -33.82932638979883],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Cremorne Veterinary Hospital '
#                                                'and Council Pound',
#                               'address_line2': 'Cabramatta Road, Mosman NSW '
#                                                '2088, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'veterinary',
#                                                      'name': 'Cremorne '
#                                                              'Veterinary '
#                                                              'Hospital and '
#                                                              'Council Pound',
#                                                      'osm_id': 110163974,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3384,
#                               'district': 'Lower North Shore',
#                               'formatted': 'Cremorne Veterinary Hospital and '
#                                            'Council Pound, Cabramatta Road, '
#                                            'Mosman NSW 2088, Australia',
#                               'lat': -33.829325,
#                               'lon': 151.2303312200312,
#                               'municipality': 'Mosman Municipal Council',
#                               'name': 'Cremorne Veterinary Hospital and '
#                                       'Council Pound',
#                               'neighbourhood': 'Spit Junction',
#                               'place_id': '51383614e05ee7624059a7f2fc5d27ea40c0f00102f90106f890060000000092032e4372656d6f726e65205665746572696e61727920486f73706974616c20616e6420436f756e63696c20506f756e64',
#                               'postcode': '2088',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Cabramatta Road',
#                               'suburb': 'Mosman'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.24286095274545,
#                                             -33.878223413796256],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Vet HQ Double Bay',
#                               'address_line2': '389 New South Head Road, '
#                                                'Double Bay NSW 2028, Australia',
#                               'categories': ['building',
#                                              'pet',
#                                              'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': 389,
#                                                      'addr:postcode': 2028,
#                                                      'addr:state': 'NSW',
#                                                      'addr:street': 'New South '
#                                                                     'Head Road',
#                                                      'addr:suburb': 'Double '
#                                                                     'Bay',
#                                                      'amenity': 'veterinary',
#                                                      'building': 'yes',
#                                                      'name': 'Vet HQ Double '
#                                                              'Bay',
#                                                      'operator': 'Vet HQ',
#                                                      'osm_id': 831608611,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 3447,
#                               'district': 'Eastern Suburbs',
#                               'formatted': 'Vet HQ Double Bay, 389 New South '
#                                            'Head Road, Double Bay NSW 2028, '
#                                            'Australia',
#                               'housenumber': '389',
#                               'lat': -33.878275849999994,
#                               'lon': 151.24288867214653,
#                               'municipality': 'Woollahra Municipal Council',
#                               'name': 'Vet HQ Double Bay',
#                               'place_id': '518c305584c5e76240590f6bf49f69f040c0f00102f901235791310000000092031156657420485120446f75626c6520426179',
#                               'postcode': '2028',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'New South Head Road',
#                               'suburb': 'Double Bay'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.24278669999998,
#                                             -33.87810009966843],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Vet HQ',
#                               'address_line2': '389 New South Head Road, '
#                                                'Double Bay NSW 2028, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'veterinary',
#                                                      'name': 'Vet HQ',
#                                                      'osm_id': 4928567066,
#                                                      'osm_type': 'n',
#                                                      'phone': '+61 2 93261255'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.contact'],
#                               'distance': 3454,
#                               'district': 'Eastern Suburbs',
#                               'formatted': 'Vet HQ, 389 New South Head Road, '
#                                            'Double Bay NSW 2028, Australia',
#                               'housenumber': '389',
#                               'lat': -33.8781001,
#                               'lon': 151.2427867,
#                               'municipality': 'Woollahra Municipal Council',
#                               'name': 'Vet HQ',
#                               'place_id': '51eb0c9de8c4e76240595a58859565f040c0f00103f9011af7c32501000000920306566574204851',
#                               'postcode': '2028',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'New South Head Road',
#                               'suburb': 'Double Bay'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2386066, -33.83214424966032],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Mosman Veterinary Clinic',
#                               'address_line2': 'Canrobert Street, Mosman NSW '
#                                                '2088, Australia',
#                               'categories': ['building',
#                                              'pet',
#                                              'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'veterinary',
#                                                      'building': 'yes',
#                                                      'name': 'Mosman '
#                                                              'Veterinary '
#                                                              'Clinic',
#                                                      'osm_id': 110163976,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3518,
#                               'district': 'Lower North Shore',
#                               'formatted': 'Mosman Veterinary Clinic, '
#                                            'Canrobert Street, Mosman NSW 2088, '
#                                            'Australia',
#                               'lat': -33.83214425,
#                               'lon': 151.2386066,
#                               'municipality': 'Mosman Municipal Council',
#                               'name': 'Mosman Veterinary Clinic',
#                               'place_id': '5183f34eaaa2e76240593aece8b383ea40c0f00102f90108f89006000000009203184d6f736d616e205665746572696e61727920436c696e6963',
#                               'postcode': '2088',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Canrobert Street',
#                               'suburb': 'Mosman'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.24449289999998,
#                                             -33.87744329966832],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Petbarn',
#                               'address_line2': 'Kiaora Road, Double Bay NSW '
#                                                '2028, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'name': 'Petbarn',
#                                                      'osm_id': 4925657661,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3525,
#                               'district': 'Eastern Suburbs',
#                               'formatted': 'Petbarn, Kiaora Road, Double Bay '
#                                            'NSW 2028, Australia',
#                               'lat': -33.8774433,
#                               'lon': 151.2444929,
#                               'municipality': 'Woollahra Municipal Council',
#                               'name': 'Petbarn',
#                               'place_id': '515533c6e2d2e7624059bb15e20f50f040c0f00103f9013d929725010000009203075065746261726e',
#                               'postcode': '2028',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Kiaora Road',
#                               'suburb': 'Double Bay'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.18535439999997,
#                                             -33.877531799668326],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Pets on the Point',
#                               'address_line2': '325 Glebe Point Road, Glebe '
#                                                'NSW 2037, Australia',
#                               'categories': ['commercial',
#                                              'pet',
#                                              'pet.service'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'name': 'Pets on the '
#                                                              'Point',
#                                                      'osm_id': 7802359154,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet_grooming',
#                                                      'website': 'https://www.petsonthepoint.com.au'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 3560,
#                               'district': 'Inner West',
#                               'formatted': 'Pets on the Point, 325 Glebe Point '
#                                            'Road, Glebe NSW 2037, Australia',
#                               'housenumber': '325',
#                               'lat': -33.8775318,
#                               'lon': 151.1853544,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Pets on the Point',
#                               'place_id': '516dc5596ceee5624059436346f652f040c0f00103f901728d0ed10100000092031150657473206f6e2074686520506f696e74',
#                               'postcode': '2037',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Glebe Point Road',
#                               'suburb': 'Glebe'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.206435714581,
#                                             -33.8240107619266],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'West Street',
#                               'address_line2': 'Crows Nest NSW 2065, Australia',
#                               'categories': ['pet', 'pet.dog_park'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'leisure': 'dog_park',
#                                                      'osm_id': 611927861,
#                                                      'osm_type': 'w',
#                                                      'surface': 'grass'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3687,
#                               'district': 'Lower North Shore',
#                               'formatted': 'West Street, Crows Nest NSW 2065, '
#                                            'Australia',
#                               'lat': -33.82407275,
#                               'lon': 151.20644829066885,
#                               'municipality': 'North Sydney Council',
#                               'neighbourhood': 'Crows Nest Junction',
#                               'place_id': '51425b121f9be66240596e03452f79e940c0f00102f9013547792400000000',
#                               'postcode': '2065',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'West Street',
#                               'suburb': 'Crows Nest'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2309394, -33.88780509967016],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Paddo Pets Dog Grooming',
#                               'address_line2': 'Oxford Street, Paddington NSW '
#                                                '2021, Australia',
#                               'categories': ['commercial',
#                                              'pet',
#                                              'pet.service'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'name': 'Paddo Pets Dog '
#                                                              'Grooming',
#                                                      'osm_id': 5901274125,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet_grooming'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3697,
#                               'district': 'Five Ways',
#                               'formatted': 'Paddo Pets Dog Grooming, Oxford '
#                                            'Street, Paddington NSW 2021, '
#                                            'Australia',
#                               'lat': -33.8878051,
#                               'lon': 151.2309394,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Paddo Pets Dog Grooming',
#                               'place_id': '51744b06db63e76240591627f698a3f140c0f00103f9010d4cbe5f01000000920317506164646f205065747320446f672047726f6f6d696e67',
#                               'postcode': '2021',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Oxford Street',
#                               'suburb': 'Paddington'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2135777, -33.89178589967087],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Surry Hills Vet',
#                               'address_line2': 'Cleveland Street, Redfern NSW '
#                                                '2010, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'veterinary',
#                                                      'name': 'Surry Hills Vet',
#                                                      'osm_id': 5608349161,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3839,
#                               'district': 'Strawberry Hills',
#                               'formatted': 'Surry Hills Vet, Cleveland Street, '
#                                            'Redfern NSW 2010, Australia',
#                               'lat': -33.8917859,
#                               'lon': 151.2135777,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Surry Hills Vet',
#                               'place_id': '51f594e6a0d5e6624059670f550a26f240c0f00103f901e99d484e0100000092030f53757272792048696c6c7320566574',
#                               'postcode': '2010',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Cleveland Street',
#                               'suburb': 'Redfern'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.200736, -33.82283299965868],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Petbarn',
#                               'address_line2': '160 Willoughby Road, Crows '
#                                                'Nest NSW 2065, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:country': 'AU',
#                                                      'addr:housenumber': 160,
#                                                      'addr:postcode': 2065,
#                                                      'addr:state': 'NSW',
#                                                      'addr:street': 'Willoughby '
#                                                                     'Road',
#                                                      'addr:suburb': 'Crows '
#                                                                     'Nest',
#                                                      'brand': 'Petbarn',
#                                                      'brand:wikidata': 'Q104746468',
#                                                      'name': 'Petbarn',
#                                                      'operator': 'Petbarn',
#                                                      'osm_id': 2625901404,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet',
#                                                      'website': 'https://www.petbarn.com.au/store-finder/crows-nest'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 4038,
#                               'district': 'Lower North Shore',
#                               'formatted': 'Petbarn, 160 Willoughby Road, '
#                                            'Crows Nest NSW 2065, Australia',
#                               'housenumber': '160',
#                               'lat': -33.822833,
#                               'lon': 151.200736,
#                               'municipality': 'North Sydney Council',
#                               'name': 'Petbarn',
#                               'neighbourhood': 'Crows Nest Junction',
#                               'place_id': '512864e76d6ce662405943cd7b9752e940c0f00103f9015c13849c000000009203075065746261726e',
#                               'postcode': '2065',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Willoughby Road',
#                               'suburb': 'Crows Nest'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.19890859999998,
#                                             -33.82270679965867],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'North Shore Vetenary Hospital',
#                               'address_line2': '64 Atchison Street, St '
#                                                'Leonards NSW 2065, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Crows Nest',
#                                                      'addr:housenumber': 64,
#                                                      'addr:postcode': 2065,
#                                                      'addr:street': 'Atchison '
#                                                                     'Street',
#                                                      'amenity': 'veterinary',
#                                                      'name': 'North Shore '
#                                                              'Vetenary '
#                                                              'Hospital',
#                                                      'osm_id': 2626474344,
#                                                      'osm_type': 'n',
#                                                      'phone': '+61 2 9436 1213',
#                                                      'website': 'https://www.northshorevet.com.au/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 4110,
#                               'district': 'Lower North Shore',
#                               'formatted': 'North Shore Vetenary Hospital, 64 '
#                                            'Atchison Street, St Leonards NSW '
#                                            '2065, Australia',
#                               'housenumber': '64',
#                               'lat': -33.8227068,
#                               'lon': 151.1989086,
#                               'municipality': 'North Sydney Council',
#                               'name': 'North Shore Vetenary Hospital',
#                               'neighbourhood': 'Crows Nest Junction',
#                               'place_id': '51947c91755de66240598b5dd7744ee940c0f00103f90168d18c9c0000000092031d4e6f7274682053686f726520566574656e61727920486f73706974616c',
#                               'postcode': '2065',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Atchison Street',
#                               'suburb': 'St Leonards'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.1758722, -33.87607649966807],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Pet O',
#                               'address_line2': '1A The Crescent, Annandale NSW '
#                                                '2038, Australia',
#                               'categories': ['commercial',
#                                              'commercial.pet',
#                                              'pet',
#                                              'pet.shop'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': '1A',
#                                                      'addr:street': 'The '
#                                                                     'Crescent',
#                                                      'name': 'Pet O',
#                                                      'osm_id': 7726482861,
#                                                      'osm_type': 'n',
#                                                      'shop': 'pet',
#                                                      'website': 'https://peto.com.au/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 4192,
#                               'district': 'Inner West',
#                               'formatted': 'Pet O, 1A The Crescent, Annandale '
#                                            'NSW 2038, Australia',
#                               'housenumber': '1A',
#                               'lat': -33.8760765,
#                               'lon': 151.1758722,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'Pet O',
#                               'place_id': '51d168bcbea0e56240592c6f554623f040c0f00103f901adc588cc01000000920305506574204f',
#                               'postcode': '2038',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'The Crescent',
#                               'suburb': 'Annandale'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.18223749999999,
#                                             -33.88578509966978],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'University of Sydney '
#                                                'Veterinary Clinic',
#                               'address_line2': '65 Orphan School Creek Lane, '
#                                                'Camperdown NSW 2050, Australia',
#                               'categories': ['pet', 'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': 65,
#                                                      'amenity': 'veterinary',
#                                                      'name': 'University of '
#                                                              'Sydney '
#                                                              'Veterinary '
#                                                              'Clinic',
#                                                      'osm_id': 515929955,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 4395,
#                               'district': 'Inner West',
#                               'formatted': 'University of Sydney Veterinary '
#                                            'Clinic, 65 Orphan School Creek '
#                                            'Lane, Camperdown NSW 2050, '
#                                            'Australia',
#                               'housenumber': '65',
#                               'lat': -33.8857851,
#                               'lon': 151.1822375,
#                               'municipality': 'Council of the City of Sydney',
#                               'name': 'University of Sydney Veterinary Clinic',
#                               'place_id': '515ad3bce3d4e5624059d32ef96761f140c0f00103f9016377c01e00000000920326556e6976657273697479206f66205379646e6579205665746572696e61727920436c696e6963',
#                               'postcode': '2050',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Orphan School Creek Lane',
#                               'suburb': 'Camperdown'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2091852111518,
#                                             -33.81728059440606],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'West Street',
#                               'address_line2': 'Naremburn NSW 2065, Australia',
#                               'categories': ['pet', 'pet.dog_park'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'leisure': 'dog_park',
#                                                      'osm_id': 482588232,
#                                                      'osm_type': 'w',
#                                                      'wheelchair': 'no'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.facilities'],
#                               'distance': 4444,
#                               'district': 'Lower North Shore',
#                               'formatted': 'West Street, Naremburn NSW 2065, '
#                                            'Australia',
#                               'lat': -33.8172838,
#                               'lon': 151.2091796978694,
#                               'municipality': 'Willoughby City Council',
#                               'place_id': '5186162fa5b1e6624059925088a69ce840c0f00102f90148b6c31c00000000',
#                               'postcode': '2065',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'West Street',
#                               'suburb': 'Naremburn'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [151.2558331396748,
#                                             -33.83484790670093],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'The Barracks Vet Surgery',
#                               'address_line2': 'Best Avenue, Mosman NSW 2088, '
#                                                'Australia',
#                               'categories': ['building',
#                                              'pet',
#                                              'pet.veterinary'],
#                               'city': 'Sydney',
#                               'country': 'Australia',
#                               'country_code': 'au',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'veterinary',
#                                                      'building': 'yes',
#                                                      'name': 'The Barracks Vet '
#                                                              'Surgery',
#                                                      'osm_id': 110163975,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 4489,
#                               'district': 'Lower North Shore',
#                               'formatted': 'The Barracks Vet Surgery, Best '
#                                            'Avenue, Mosman NSW 2088, Australia',
#                               'lat': -33.834854,
#                               'lon': 151.25583766684548,
#                               'municipality': 'Mosman Municipal Council',
#                               'name': 'The Barracks Vet Surgery',
#                               'neighbourhood': 'Balmoral',
#                               'place_id': '515c04fbc82fe86240591035d44bdcea40c0f00102f90107f8900600000000920318546865204261727261636b73205665742053757267657279',
#                               'postcode': '2088',
#                               'state': 'New South Wales',
#                               'state_code': 'NSW',
#                               'street': 'Best Avenue',
#                               'suburb': 'Mosman'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Loop through the features and print coordinates and categories
for feature in x['features']:
    coords = feature['geometry']['coordinates']
    categories = feature['properties']['categories']
    print(f"Coordinates: {coords}, Categories: {categories}")
# Out:
# Coordinates: [151.22785899999997, -33.87202299966735], Categories: ['commercial', 'commercial.pet', 'pet', 'pet.shop']
# Coordinates: [151.21709679999998, -33.87775229966837], Categories: ['commercial', 'pet', 'pet.service']
# Coordinates: [151.2394564, -33.84184549966201], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.2252803, -33.884726599669605], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.18053139999998, -33.857732799664824], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.23033145854583, -33.82932638979883], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.24286095274545, -33.878223413796256], Categories: ['building', 'pet', 'pet.veterinary']
# Coordinates: [151.24278669999998, -33.87810009966843], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.2386066, -33.83214424966032], Categories: ['building', 'pet', 'pet.veterinary']
# Coordinates: [151.24449289999998, -33.87744329966832], Categories: ['commercial', 'commercial.pet', 'pet', 'pet.shop']
# Coordinates: [151.18535439999997, -33.877531799668326], Categories: ['commercial', 'pet', 'pet.service']
# Coordinates: [151.206435714581, -33.8240107619266], Categories: ['pet', 'pet.dog_park']
# Coordinates: [151.2309394, -33.88780509967016], Categories: ['commercial', 'pet', 'pet.service']
# Coordinates: [151.2135777, -33.89178589967087], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.200736, -33.82283299965868], Categories: ['commercial', 'commercial.pet', 'pet', 'pet.shop']
# Coordinates: [151.19890859999998, -33.82270679965867], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.1758722, -33.87607649966807], Categories: ['commercial', 'commercial.pet', 'pet', 'pet.shop']
# Coordinates: [151.18223749999999, -33.88578509966978], Categories: ['pet', 'pet.veterinary']
# Coordinates: [151.2091852111518, -33.81728059440606], Categories: ['pet', 'pet.dog_park']
# Coordinates: [151.2558331396748, -33.83484790670093], Categories: ['building', 'pet', 'pet.veterinary']

# %%
len(x['features'])
# Out:
# 20

# %%
# Print the results
print(x['features'][0]['properties']['address_line1'])
print(x['features'][0]['properties']['address_line2'])
# Out:
# Healthy Everyday Pets
# 43-47 Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia

# %% [markdown]
# ## 5. Find the nearest dentist to your house.
#
# > **Hint:** Use Geoapify Geocode to find your latitude and Geoapify Places to find the dentist.

# %%
# Geoapify Geocode to find latitude and longitude
target_city = "313%20K%20ST%20NE%20Washington%20DC%20United%20States%20of%20America"

# Build URL using the geocode endpoint
url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"

# %%
# Run request
x = requests.get(url).json()

# Print the json (pretty printed)
pprint(x)
# Out:
# {'query': {'parsed': {'city': 'washington',
#                       'country': 'united states of america',
#                       'expected_type': 'building',
#                       'housenumber': '313',
#                       'state': 'dc',
#                       'street': 'k st ne'},
#            'text': '313 K ST NE Washington DC United States of America'},
#  'results': [{'address_line1': '313 K Street Northeast',
#               'address_line2': 'Washington, DC 20426, United States of America',
#               'bbox': {'lat1': 38.9021776,
#                        'lat2': 38.9023163,
#                        'lon1': -77.001544,
#                        'lon2': -77.0014889},
#               'category': 'building',
#               'city': 'Washington',
#               'country': 'United States',
#               'country_code': 'us',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': '313 K Street Northeast, Washington, DC 20426, '
#                            'United States of America',
#               'housenumber': '313',
#               'lat': 38.902259099999995,
#               'lon': -77.00151626438807,
#               'place_id': '515e7dacd7184053c0595a82e7397d734340f00102f901d237fb0300000000c00203',
#               'plus_code': '87C4WX2X+W9',
#               'postcode': '20426',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'confidence_street_level': 1,
#                        'importance': 0.41000999999999993,
#                        'match_type': 'full_match',
#                        'popularity': 7.246596402418312},
#               'result_type': 'building',
#               'state': 'District of Columbia',
#               'state_code': 'DC',
#               'street': 'K Street Northeast',
#               'suburb': 'Near Northeast',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/New_York',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}},
#              {'address_line1': '313 K Street Northeast',
#               'address_line2': 'Washington, DC 20002, United States of America',
#               'bbox': {'lat1': 38.902382422504,
#                        'lat2': 38.902482422504,
#                        'lon1': -77.001785306323,
#                        'lon2': -77.001685306323},
#               'city': 'Washington',
#               'country': 'United States',
#               'country_code': 'us',
#               'datasource': {'attribution': '© OpenStreetMap contributors',
#                              'license': 'Open Database License',
#                              'sourcename': 'openstreetmap',
#                              'url': 'https://www.openstreetmap.org/copyright'},
#               'formatted': '313 K Street Northeast, Washington, DC 20002, '
#                            'United States of America',
#               'housenumber': '313',
#               'lat': 38.90243242250354,
#               'lon': -77.00173530632308,
#               'place_id': '51fff9666e1c4053c0595ac0d6e782734340f00102f9011db8d20500000000c00203',
#               'plus_code': '87C4WX2X+X8',
#               'postcode': '20002',
#               'rank': {'confidence': 1,
#                        'confidence_city_level': 1,
#                        'confidence_street_level': 1,
#                        'importance': -0.74,
#                        'match_type': 'full_match',
#                        'popularity': 7.246596402418312},
#               'result_type': 'building',
#               'state': 'District of Columbia',
#               'state_code': 'DC',
#               'street': 'K Street Northeast',
#               'suburb': 'Near Northeast',
#               'timezone': {'abbreviation_DST': 'EDT',
#                            'abbreviation_STD': 'EST',
#                            'name': 'America/New_York',
#                            'offset_DST': '-04:00',
#                            'offset_DST_seconds': -14400,
#                            'offset_STD': '-05:00',
#                            'offset_STD_seconds': -18000}}]}

# %%
# Extract lat/lon
_ =x['results'][0]
lat = _['lat']
lon = _['lon']

# Print results
print(f"{_['address_line1']}, {_['address_line2']}: {lat} {lon}")
# Out:
# 313 K Street Northeast, Washington, DC 20426, United States of America: 38.902259099999995 -77.00151626438807

# %%
# set up a parameters dictionary
params = {
    # Set the geographical coordinates for my home
    'lat': lat,
    'lon': lon,
    # Set the parameters for the type of place
    'type': 'healthcare.dentist',
    # Set the parameters for the type of search
    'search_type': 'nearby',
    'sort': 'distance',
    'limit': 1,
    'apiKey': geoapify_key,
}


# Set base URL
url = f"https://api.geoapify.com/v2/places"

# Run request
x = requests.get(url, params=params).json()

# Print the json (pretty printed)
pprint(x)
# Out:
# {'features': [{'geometry': {'coordinates': [-76.99591049999998,
#                                             38.902243600111724],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Advance Dental Care DC',
#                               'address_line2': '701 7th Street Northeast, '
#                                                'Washington, DC 20002, United '
#                                                'States of America',
#                               'categories': ['healthcare',
#                                              'healthcare.dentist'],
#                               'city': 'Washington',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Washington',
#                                                      'addr:housenumber': 701,
#                                                      'addr:postcode': 20002,
#                                                      'addr:state': 'DC',
#                                                      'addr:street': 'K Street '
#                                                                     'Northeast;K '
#                                                                     'St NE',
#                                                      'amenity': 'dentist',
#                                                      'healthcare': 'dentist',
#                                                      'name': 'Advance Dental '
#                                                              'Care DC',
#                                                      'osm_id': 776716749,
#                                                      'osm_type': 'n',
#                                                      'phone': '202-546-0690',
#                                                      'website': 'http://advancedentalcaredc.com'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 486,
#                               'formatted': 'Advance Dental Care DC, 701 7th '
#                                            'Street Northeast, Washington, DC '
#                                            '20002, United States of America',
#                               'housenumber': '701',
#                               'lat': 38.9022436,
#                               'lon': -76.9959105,
#                               'name': 'Advance Dental Care DC',
#                               'place_id': '518ccf64ffbc3f53c059a9c0e1b77c734340f00103f901cdc14b2e00000000920316416476616e63652044656e74616c2043617265204443',
#                               'postcode': '20002',
#                               'state': 'District of Columbia',
#                               'state_code': 'DC',
#                               'street': '7th Street Northeast',
#                               'suburb': 'Near Northeast'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print the results
print(f"""{x['features'][0]['properties']['name']}
{x['features'][0]['properties']['address_line2']}""")
# Out:
# Advance Dental Care DC
# 701 7th Street Northeast, Washington, DC 20002, United States of America

# %% [markdown]
# ## 6. Bonus: Find the names and addresses of the five nearest restaurants with internet access in your home city area.
#
# > **Hint:** Read about the `proximity` bias to order the results from the nearest to the farest place. Also, read about the `conditions` to identify places that provide internet access.

# %%
# set up a parameters dictionary
params = {
    # Set the geographical coordinates for my home
    'lat': lat,
    'lon': lon,
    # Set the parameters for the type of place
    'type': 'catering.restaurant',
    # Set the parameters for the type of search
    'limit': 5,
    'sort': 'distance',
    'categories': 'internet_access',
    'apiKey': geoapify_key,
}

# Set base URL
url = 'https://api.geoapify.com/v2/places'

# Run request
x = requests.get(url, params=params).json()

# Print the json (pretty printed)
pprint(x)
# Out:
# {'features': [{'geometry': {'coordinates': [-77.00326889999998,
#                                             38.90290970011183],
#                             'type': 'Point'},
#                'properties': {'address_line1': '200 K Street Northeast',
#                               'address_line2': 'Washington, DC 20002, United '
#                                                'States of America',
#                               'categories': ['catering',
#                                              'catering.cafe',
#                                              'internet_access'],
#                               'city': 'Washington',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'cafe',
#                                                      'internet_access': 'yes',
#                                                      'opening_hours': '24/7',
#                                                      'opening_hours:covid19': 'closed',
#                                                      'osm_id': 9285430489,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 168,
#                               'district': 'NoMa',
#                               'formatted': '200 K Street Northeast, '
#                                            'Washington, DC 20002, United '
#                                            'States of America',
#                               'housenumber': '200',
#                               'lat': 38.9029097,
#                               'lon': -77.0032689,
#                               'place_id': '5101a6c28e354053c059599c888b92734340f00103f901d96c742902000000',
#                               'postcode': '20002',
#                               'state': 'District of Columbia',
#                               'state_code': 'DC',
#                               'street': 'K Street Northeast',
#                               'suburb': 'Near Northeast'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-77.000308, 38.900074200111426],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Batter Bowl Bakery',
#                               'address_line2': '403A H Street Northeast, '
#                                                'Washington, DC 20002, United '
#                                                'States of America',
#                               'categories': ['commercial',
#                                              'commercial.food_and_drink',
#                                              'commercial.food_and_drink.bakery',
#                                              'internet_access'],
#                               'city': 'Washington',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Washington',
#                                                      'addr:housenumber': '403A',
#                                                      'addr:postcode': 20002,
#                                                      'addr:street': 'H Street '
#                                                                     'Northeast',
#                                                      'internet_access': 'wlan',
#                                                      'name': 'Batter Bowl '
#                                                              'Bakery',
#                                                      'osm_id': 3137411785,
#                                                      'osm_type': 'n',
#                                                      'shop': 'bakery',
#                                                      'website': 'http://www.the-bbb.com/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.facilities'],
#                               'distance': 264,
#                               'formatted': 'Batter Bowl Bakery, 403A H Street '
#                                            'Northeast, Washington, DC 20002, '
#                                            'United States of America',
#                               'housenumber': '403A',
#                               'lat': 38.9000742,
#                               'lon': -77.000308,
#                               'name': 'Batter Bowl Bakery',
#                               'place_id': '51577bd80b054053c059d9b9a2a135734340f00103f901c91a01bb0000000092031242617474657220426f776c2042616b657279',
#                               'postcode': '20002',
#                               'state': 'District of Columbia',
#                               'state_code': 'DC',
#                               'street': 'H Street Northeast',
#                               'suburb': 'Near Northeast'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-76.99812799999998,
#                                             38.90038820011146],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Whole Foods Market',
#                               'address_line2': '600 H Street Northeast, '
#                                                'Washington, DC 20002, United '
#                                                'States of America',
#                               'categories': ['commercial',
#                                              'commercial.supermarket',
#                                              'internet_access'],
#                               'city': 'Washington',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Washington',
#                                                      'addr:housenumber': 600,
#                                                      'addr:postcode': 20002,
#                                                      'addr:state': 'DC',
#                                                      'addr:street': 'H Street '
#                                                                     'Northeast',
#                                                      'brand': 'Whole Foods '
#                                                               'Market',
#                                                      'brand:wikidata': 'Q1809448',
#                                                      'brand:wikipedia': 'en:Whole '
#                                                                         'Foods '
#                                                                         'Market',
#                                                      'internet_access': 'wlan',
#                                                      'name': 'Whole Foods '
#                                                              'Market',
#                                                      'opening_hours': 'Mo-Su '
#                                                                       '07:00-23:00',
#                                                      'osm_id': 4796814275,
#                                                      'osm_type': 'n',
#                                                      'phone': '+1-202-469-7410',
#                                                      'shop': 'supermarket',
#                                                      'website': 'https://www.wholefoodsmarket.com/stores/hstreet'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.contact',
#                                           'details.facilities'],
#                               'distance': 360,
#                               'formatted': 'Whole Foods Market, 600 H Street '
#                                            'Northeast, Washington, DC 20002, '
#                                            'United States of America',
#                               'housenumber': '600',
#                               'lat': 38.9003882,
#                               'lon': -76.998128,
#                               'name': 'Whole Foods Market',
#                               'place_id': '51324e4354e13f53c0596d97a8eb3f734340f00103f901c393e91d0100000092031257686f6c6520466f6f6473204d61726b6574',
#                               'postcode': '20002',
#                               'state': 'District of Columbia',
#                               'state_code': 'DC',
#                               'street': 'H Street Northeast',
#                               'suburb': 'Near Northeast'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-76.9972548, 38.90039100011146],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'The Wydown',
#                               'address_line2': '600B H Street Northeast, '
#                                                'Washington, DC 20002, United '
#                                                'States of America',
#                               'categories': ['catering',
#                                              'catering.cafe',
#                                              'internet_access'],
#                               'city': 'Washington',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': '600B',
#                                                      'addr:postcode': 20002,
#                                                      'addr:street': 'H Street '
#                                                                     'Northeast',
#                                                      'amenity': 'cafe',
#                                                      'internet_access': 'wlan',
#                                                      'name': 'The Wydown',
#                                                      'opening_hours': 'Su-Mo '
#                                                                       '07:00-18:00; '
#                                                                       'Tu-Sa '
#                                                                       '07:00-22:00',
#                                                      'osm_id': 5503443221,
#                                                      'osm_type': 'n',
#                                                      'phone': '(202)846-7986',
#                                                      'website': 'https://thewydown.com/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.contact',
#                                           'details.facilities'],
#                               'distance': 424,
#                               'formatted': 'The Wydown, 600B H Street '
#                                            'Northeast, Washington, DC 20002, '
#                                            'United States of America',
#                               'housenumber': '600B',
#                               'lat': 38.900391,
#                               'lon': -76.9972548,
#                               'name': 'The Wydown',
#                               'place_id': '51dbf1cb05d33f53c059b58b250340734340f00103f90115e107480100000092030a546865205779646f776e',
#                               'postcode': '20002',
#                               'state': 'District of Columbia',
#                               'state_code': 'DC',
#                               'street': 'H Street Northeast',
#                               'suburb': 'Near Northeast'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-76.99744109999999,
#                                             38.90003470011141],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Starbucks',
#                               'address_line2': '625 H Street Northeast, '
#                                                'Washington, DC 20002, United '
#                                                'States of America',
#                               'categories': ['catering',
#                                              'catering.cafe',
#                                              'catering.cafe.coffee',
#                                              'catering.cafe.coffee_shop',
#                                              'internet_access'],
#                               'city': 'Washington',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Washington',
#                                                      'addr:housenumber': 625,
#                                                      'addr:postcode': 20002,
#                                                      'addr:state': 'DC',
#                                                      'addr:street': 'H Street '
#                                                                     'Northeast',
#                                                      'amenity': 'cafe',
#                                                      'branch': 'Signing Store',
#                                                      'brand': 'Starbucks',
#                                                      'brand:wikidata': 'Q37158',
#                                                      'brand:wikipedia': 'en:Starbucks',
#                                                      'cuisine': 'coffee_shop',
#                                                      'deaf': 'yes',
#                                                      'deaf:description:en': 'The '
#                                                                             'shop '
#                                                                             'is '
#                                                                             'led '
#                                                                             'by '
#                                                                             'a '
#                                                                             'team '
#                                                                             'of '
#                                                                             'employees '
#                                                                             'who '
#                                                                             'are '
#                                                                             'all '
#                                                                             'fluent '
#                                                                             'in '
#                                                                             'American '
#                                                                             'Sign '
#                                                                             'Language '
#                                                                             '(ASL).',
#                                                      'internet_access': 'wlan',
#                                                      'name': 'Starbucks',
#                                                      'official_name': 'Starbucks '
#                                                                       'Coffee',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '05:30-21:00; '
#                                                                       'Sa-Su '
#                                                                       '07:00-20:00',
#                                                      'osm_id': 4974355669,
#                                                      'osm_type': 'n',
#                                                      'outdoor_seating': 'yes',
#                                                      'phone': '+1-202-807-8439',
#                                                      'takeaway': 'yes'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.catering',
#                                           'details.contact',
#                                           'details.facilities'],
#                               'distance': 431,
#                               'formatted': 'Starbucks, 625 H Street Northeast, '
#                                            'Washington, DC 20002, United '
#                                            'States of America',
#                               'housenumber': '625',
#                               'lat': 38.9000347,
#                               'lon': -76.9974411,
#                               'name': 'Starbucks',
#                               'place_id': '51eb0b3213d63f53c059311f495634734340f00103f901d5a47e2801000000920309537461726275636b73',
#                               'postcode': '20002',
#                               'state': 'District of Columbia',
#                               'state_code': 'DC',
#                               'street': 'H Street Northeast',
#                               'suburb': 'Near Northeast'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
# Print the results
for _ in x['features']:
    print(f"{_['properties']['address_line1']}")
# Out:
# 200 K Street Northeast
# Batter Bowl Bakery
# Whole Foods Market
# The Wydown
# Starbucks
