# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=5000, centers=2, n_features=2, random_state=42, cluster_std=3)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
plt.show()

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 15
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 21 (84.00 Byte)
# Trainable params: 21 (84.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 118/118 [==============================] - 1s 1ms/step - loss: 0.4776 - accuracy: 0.9267
# Epoch 2/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3447 - accuracy: 0.9373
# Epoch 3/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2528 - accuracy: 0.9416
# Epoch 4/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.9451
# Epoch 5/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1674 - accuracy: 0.9475
# Epoch 6/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1498 - accuracy: 0.9488
# Epoch 7/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1396 - accuracy: 0.9507
# Epoch 8/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9504
# Epoch 9/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1299 - accuracy: 0.9512
# Epoch 10/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.9515
# Epoch 11/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1262 - accuracy: 0.9504
# Epoch 12/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9509
# Epoch 13/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1248 - accuracy: 0.9504
# Epoch 14/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1244 - accuracy: 0.9504
# Epoch 15/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1242 - accuracy: 0.9501
# Epoch 16/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 0.9504
# Epoch 17/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1238 - accuracy: 0.9501
# Epoch 18/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1238 - accuracy: 0.9504
# Epoch 19/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9509
# Epoch 20/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1236 - accuracy: 0.9504
# Epoch 21/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1236 - accuracy: 0.9499
# Epoch 22/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1235 - accuracy: 0.9504
# Epoch 23/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.9507
# Epoch 24/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1235 - accuracy: 0.9493
# Epoch 25/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.9504
# Epoch 26/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.9507
# Epoch 27/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.9504
# Epoch 28/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.9507
# Epoch 29/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1232 - accuracy: 0.9501
# Epoch 30/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1232 - accuracy: 0.9504
# Epoch 31/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1232 - accuracy: 0.9507
# Epoch 32/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1231 - accuracy: 0.9499
# Epoch 33/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1231 - accuracy: 0.9507
# Epoch 34/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9504
# Epoch 35/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9504
# Epoch 36/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9509
# Epoch 37/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9512
# Epoch 38/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9507
# Epoch 39/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 40/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9509
# Epoch 41/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1228 - accuracy: 0.9512
# Epoch 42/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1228 - accuracy: 0.9504
# Epoch 43/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9507
# Epoch 44/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1228 - accuracy: 0.9507
# Epoch 45/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1227 - accuracy: 0.9499
# Epoch 46/50
# 118/118 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9507
# Epoch 47/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9515
# Epoch 48/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9504
# Epoch 49/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9504
# Epoch 50/50
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9507

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 40/40 - 0s - loss: 0.1231 - accuracy: 0.9520 - 165ms/epoch - 4ms/step
# Loss: 0.12311059236526489, Accuracy: 0.9520000219345093

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
history_df.plot(y="accuracy")
plt.show()
