# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
plt.show()

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 15
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 21 (84.00 Byte)
# Trainable params: 21 (84.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 3s 1ms/step - loss: 1.1570 - accuracy: 0.0333
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0800 - accuracy: 0.0333
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0138 - accuracy: 0.0360
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9567 - accuracy: 0.0360
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9068 - accuracy: 0.0413
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8629 - accuracy: 0.0533
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8238 - accuracy: 0.1067
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7881 - accuracy: 0.2240
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7556 - accuracy: 0.3213
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7254 - accuracy: 0.4147
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6957 - accuracy: 0.5013
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6659 - accuracy: 0.5813
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6353 - accuracy: 0.6760
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6032 - accuracy: 0.7320
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5691 - accuracy: 0.8000
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5347 - accuracy: 0.8613
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4999 - accuracy: 0.9080
# Epoch 18/100
# 24/24 [==============================] - 0s 964us/step - loss: 0.4659 - accuracy: 0.9560
# Epoch 19/100
# 24/24 [==============================] - 0s 989us/step - loss: 0.4331 - accuracy: 0.9720
# Epoch 20/100
# 24/24 [==============================] - 0s 993us/step - loss: 0.4013 - accuracy: 0.9813
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3710 - accuracy: 0.9840
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3419 - accuracy: 0.9867
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3144 - accuracy: 0.9880
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2886 - accuracy: 0.9907
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2649 - accuracy: 0.9907
# Epoch 26/100
# 24/24 [==============================] - 0s 977us/step - loss: 0.2431 - accuracy: 0.9920
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2230 - accuracy: 0.9933
# Epoch 28/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2046 - accuracy: 0.9960
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 0.9973
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1725 - accuracy: 0.9987
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1585 - accuracy: 0.9987
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1459 - accuracy: 0.9987
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1345 - accuracy: 0.9987
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1241 - accuracy: 0.9987
# Epoch 35/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1147 - accuracy: 0.9987
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1062 - accuracy: 0.9987
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0985 - accuracy: 0.9987
# Epoch 38/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0850 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0793 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0692 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0648 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0571 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 973us/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 913us/step - loss: 0.0477 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 992us/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 989us/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 957us/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 1000us/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 913us/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 940us/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 984us/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 913us/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 979us/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 986us/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 968us/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 974us/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 987us/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 964us/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 989us/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 939us/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 984us/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 949us/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 988us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 1000us/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 956us/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 987us/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
plt.show()

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
plt.show()

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0055 - accuracy: 1.0000 - 179ms/epoch - 22ms/step
# Loss: 0.005539358593523502, Accuracy: 1.0
