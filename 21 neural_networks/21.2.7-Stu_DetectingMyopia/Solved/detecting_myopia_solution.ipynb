# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
myopia_df = pd.read_csv('https://static.bc-edx.com/data/dl-1-2/m21/lessons/2/myopia.csv')
myopia_df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
# Remove MYOPIC target from features data
y = myopia_df.MYOPIC.values
X = myopia_df.drop(columns="MYOPIC").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=14))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 1ms/step - loss: 0.5619 - accuracy: 0.8229
# Epoch 2/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5080 - accuracy: 0.8618
# Epoch 3/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.8683
# Epoch 4/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4419 - accuracy: 0.8683
# Epoch 5/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8683
# Epoch 6/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8683
# Epoch 7/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.8683
# Epoch 8/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3767 - accuracy: 0.8683
# Epoch 9/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8683
# Epoch 10/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3554 - accuracy: 0.8683
# Epoch 11/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8683
# Epoch 12/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3386 - accuracy: 0.8683
# Epoch 13/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.8683
# Epoch 14/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3241 - accuracy: 0.8683
# Epoch 15/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3175 - accuracy: 0.8683
# Epoch 16/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3115 - accuracy: 0.8683
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3056 - accuracy: 0.8683
# Epoch 18/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2997 - accuracy: 0.8704
# Epoch 19/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2949 - accuracy: 0.8704
# Epoch 20/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2889 - accuracy: 0.8726
# Epoch 21/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2837 - accuracy: 0.8726
# Epoch 22/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2790 - accuracy: 0.8747
# Epoch 23/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2741 - accuracy: 0.8726
# Epoch 24/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2691 - accuracy: 0.8747
# Epoch 25/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2641 - accuracy: 0.8726
# Epoch 26/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2597 - accuracy: 0.8747
# Epoch 27/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2553 - accuracy: 0.8812
# Epoch 28/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2515 - accuracy: 0.8877
# Epoch 29/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.8898
# Epoch 30/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2423 - accuracy: 0.8898
# Epoch 31/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 0.8920
# Epoch 32/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2344 - accuracy: 0.8985
# Epoch 33/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2309 - accuracy: 0.8985
# Epoch 34/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2275 - accuracy: 0.8985
# Epoch 35/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2237 - accuracy: 0.9028
# Epoch 36/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2209 - accuracy: 0.9093
# Epoch 37/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2173 - accuracy: 0.9050
# Epoch 38/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2143 - accuracy: 0.9136
# Epoch 39/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2113 - accuracy: 0.9136
# Epoch 40/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2089 - accuracy: 0.9201
# Epoch 41/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9179
# Epoch 42/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2037 - accuracy: 0.9158
# Epoch 43/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2021 - accuracy: 0.9222
# Epoch 44/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.9158
# Epoch 45/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.9179
# Epoch 46/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.9179
# Epoch 47/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1943 - accuracy: 0.9179
# Epoch 48/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1924 - accuracy: 0.9201
# Epoch 49/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1903 - accuracy: 0.9222
# Epoch 50/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1897 - accuracy: 0.9179
# 5/5 - 0s - loss: 0.3885 - accuracy: 0.8516 - 118ms/epoch - 24ms/step
# Loss: 0.3884507715702057, Accuracy: 0.85161292552948
